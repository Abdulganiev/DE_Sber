# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
help_prog = {
    '1': 'создать таблицу clien',
    '2': 'добавить клиента в таблицу в ручном режиме указав его данные',
    '3': 'добавляет клиентов в таблицу из JSON файла',
    '4': 'вывести средний возраст клиентов',
    '0': 'выход из программы'
}

# %%
def print_help():
    print('Выберите, что хотите выполнить:')
    for key, value in help_prog.items():
        print(f'{key} - {value}')

# %%
n = -1
print_help()
while n != 0:
    n = int(input('? - '))
# Out:
# Выберите, что хотите выполнить:
# 1 - создать таблицу clien
# 2 - добавить клиента в таблицу в ручном режиме указав его данные
# 3 - добавляет клиентов в таблицу из JSON файла
# 4 - вывести средний возраст клиентов
# 0 - выход из программы
# ? - 1
# ? - 0

# %%
for key, value in help_prog.items():
    print(f'{key} - {value}')
# Out:
# 1 - создать таблицу clien
# 2 - добавить клиента в таблицу в ручном режиме указав его данные
# 3 - добавляет клиентов в таблицу из JSON файла
# 4 - вывести средний возраст клиентов
# 0 - выход из программы

# %%
import os
import json

# %%
file_path = 'd:\python\DE\DZ_04\clients.txt'
# path = os.path.basename(file_path)
# os.path.dirname
# os.chdir(os.path.dirname(path))

with open(file_path, 'r', encoding='utf-8') as file: #открыли файл
    text = json.load(file) #загнали все из файла в переменную

for line in text:
    print(line['name'], line['lastname'], line['age'])
# Out:
# Гайк Инанц 28
# Гайк1 Инанц1 29
# Гайк2 Инанц2 30

# %%
text
# Out:
# [{'name': 'Гайк', 'lastname': 'Инанц', 'age': 28},
#  {'name': 'Гайк1', 'lastname': 'Инанц1', 'age': 29},
#  {'name': 'Гайк2', 'lastname': 'Инанц2', 'age': 30}]

# %%
print(json.load(t))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-163-d3dc8187ce90> in <module>
# ----> 1 print(json.load(t))
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# AttributeError: 'str' object has no attribute 'read'

# %%
for line in t:
    print(line)
    #print(json.loads(line)['name'])
# Out:
# [
# "
# [
# \
# n
# "
# ,
#
# "
# {
# \
# n
# "
# ,
#
# "
# \
# "
# n
# a
# m
# e
# \
# "
# :
#
# \
# "
# \
# u
# 0
# 4
# 1
# 3
# \
# u
# 0
# 4
# 3
# 0
# \
# u
# 0
# 4
# 3
# 9
# \
# u
# 0
# 4
# 3
# a
# \
# "
# ,
# \
# n
# "
# ,
#
# "
# \
# "
# l
# a
# s
# t
# n
# a
# m
# e
# \
# "
# :
#
# \
# "
# \
# u
# 0
# 4
# 1
# 8
# \
# u
# 0
# 4
# 3
# d
# \
# u
# 0
# 4
# 3
# 0
# \
# u
# 0
# 4
# 3
# d
# \
# u
# 0
# 4
# 4
# 6
# \
# "
# ,
# \
# n
# "
# ,
#
# "
# \
# "
# a
# g
# e
# \
# "
# :
#
# 2
# 8
# \
# n
# "
# ,
#
# "
# }
# ,
# \
# n
# "
# ,
#
# "
# {
# \
# n
# "
# ,
#
# "
# \
# "
# n
# a
# m
# e
# \
# "
# :
#
# \
# "
# \
# u
# 0
# 4
# 1
# 3
# \
# u
# 0
# 4
# 3
# 0
# \
# u
# 0
# 4
# 3
# 9
# \
# u
# 0
# 4
# 3
# a
# 1
# \
# "
# ,
# \
# n
# "
# ,
#
# "
# \
# "
# l
# a
# s
# t
# n
# a
# m
# e
# \
# "
# :
#
# \
# "
# \
# u
# 0
# 4
# 1
# 8
# \
# u
# 0
# 4
# 3
# d
# \
# u
# 0
# 4
# 3
# 0
# \
# u
# 0
# 4
# 3
# d
# \
# u
# 0
# 4
# 4
# 6
# 1
# \
# "
# ,
# \
# n
# "
# ,
#
# "
# \
# "
# a
# g
# e
# \
# "
# ...

# %%
t = ''
for line in text:
    #print(line)
    t += line

# %%
t.replace('\n', '').replace('[', '').replace(']', '').split('},{')
# Out:
# ['{"name": "Гайк","lastname": "Инанц","age": 28',
#  '"name": "Гайк1","lastname": "Инанц1","age": 29',
#  '"name": "Гайк2","lastname": "Инанц2","age": 30}']

# %%
t
# Out:
# '[\n{\n"name": "Гайк",\n"lastname": "Инанц",\n"age": 28\n},\n{\n"name": "Гайк1",\n"lastname": "Инанц1",\n"age": 29\n},\n{\n"name": "Гайк2",\n"lastname": "Инанц2",\n"age": 30\n}\n]\n'

# %%
for i in text:
    print(json.loads(i)['name'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-99-e37f809bdf00> in <module>
#       1 for i in text:
# ----> 2     print(json.loads(i)['name'])
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ...
